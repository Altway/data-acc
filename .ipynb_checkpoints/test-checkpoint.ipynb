# %%
import seaborn as sns
import pandas as pd
import datetime

df = pd.read_csv("/home/rems/Desktop/SharedFolder/laaa.csv")


df["temperature"] = df["temperature"].apply(lambda x:float(x.replace(',','.')))
df["humidity"] = df["humidity"].apply(lambda x:float(x[:-1].replace(',','.')))
df["time"] = df["time"].apply(lambda x: datetime.datetime.strptime(x, '%Y-%m-%d %H:%M:%S'))
print(df.info())
print(df)
sns.set_theme(style="ticks")


sns.lmplot(x="time", y="temperature", col="time", hue="time", data=df,
           col_wrap=2, ci=None, palette="muted", height=4,
           scatter_kws={"s": 50, "alpha": 1})
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   time         247 non-null    datetime64[ns]
#  1   temperature  247 non-null    float64
#  2   humidity     247 non-null    float64
# dtypes: datetime64[ns](1), float64(2)
# memory usage: 5.9 KB
# None
#                    time  temperature  humidity
# 0   2020-11-15 23:52:29        20.69      74.8
# 1   2020-11-16 00:02:29        20.69      74.7
# 2   2020-11-16 00:12:29        20.69      74.6
# 3   2020-11-16 00:22:29        20.69      74.8
# 4   2020-11-16 00:32:29        20.69      74.9
# ..                  ...          ...       ...
# 242 2020-11-17 16:12:29        20.13      59.9
# 243 2020-11-17 16:22:29        20.13      60.0
# 244 2020-11-17 16:32:29        19.75      60.7
# 245 2020-11-17 16:42:29        19.69      61.1
# 246 2020-11-17 16:52:29        19.63      61.4
#
# ...
